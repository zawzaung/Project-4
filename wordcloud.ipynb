# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
import urllib
import requests
import numpy as np
import matplotlib.pyplot as plt

# %%
# This function takes in your text and your mask, generates a wordcloud and save the image. 
def generate_wordcloud(words, mask,filename):
    word_cloud = WordCloud(width = 512, height = 512, collocations=False,background_color='white', stopwords=STOPWORDS, mask=mask).generate(words)
    plt.figure(figsize=(10,8),facecolor = 'white', edgecolor='blue')
    plt.imshow(word_cloud)
    plt.axis('off')
    plt.tight_layout(pad=0)
    
    plt.savefig(filename+'.png')
    plt.show()

# %%
#Generate Word Cloud for IcedMilk Topic
milk = 'pudding, iced, iced milk, pudding boba, caramel, boba, sweet, milk, ice, caramel pudding, milk caramel, ice milk, boba pudding, milk pudding, jelly, sweetness, favorite, le, sugar, love, like, milk boba, really, favorite boba, jelly boba, still, egg, egg pudding, tried, one, le sweet, recommend, perfect, level, taste, getting, also, chewy, always, milk jelly, cream, love iced, usually, chocolate, really sweet, would, ive, ha, creamy, one favorite'
mask = np.array(Image.open('cup.jpg'))
generate_wordcloud(milk, mask,'icemilk')

# %%
chicken = 'chicken, popcorn, popcorn chicken, fry, pepper, salt, salt pepper, potato, potato fry, nugget, sweet potato, chicken nugget, pepper chicken, also, snack, food, love, good, sweet, always, fried, wing, tasty, spicy, definitely, chicken sweet, boba, great, chicken wing, pretty, recommend, favorite, best, crispy, like, area, tea, pretty good, really, size, fresh, bomb, piece, fruit, price, fry plum, theyre, spot, lot, plum powder'
mask = np.array(Image.open('chicken.jpg'))

#Generate Word Cloud for Food Topic
generate_wordcloud(chicken, mask,'food')

# %%
clock = 'minute, wait, dont, waiting, waited, like, around, im, much, took, line, good, first, would, didnt, try, ordered, thing, take, pretty, ive, really, cup, think, better, see, know, wasnt, door, one, could, hype, way, say, since, still, want, size, give, tapioca, going, night, special, maybe, cant, hour, made, probably, wait minute, area'
mask = np.array(Image.open('clock1.jpg'))

#Generate Word Cloud for Time Topic
generate_wordcloud(clock, mask,'wait')

# %%
cup = 'fit, holder, cup holder, cup, car, fit cup, dont fit, fit car, car cup, doesnt fit, big, doesnt, wont fit, holder car, cup dont, wont, dont, size, huge, fat, big cup, cute, hold, driving, one, milk, unique, fat cup, like, cup size, milk tea, tea, wide, large, ball, cup wont, thing, short, huge cup, tasted, size cup, tried, tapioca, good, take, cup doesnt, try, boba, cup unique, cupholder'
mask = np.array(Image.open('cupsize.jpg'))

#Run the following to generate your wordcloud
generate_wordcloud(cup, mask, 'size')

# %%
tea = 'green, tea, green tea, milk tea, milk, tea boba, matcha, jelly, taste, boba, fresh, oolong, like, flavor, black, peach, green milk, good, honey, matcha milk, tea jelly, ordered, lychee, milk green, tried, also, sweet, tea flavor, mango, matcha green, oolong milk, tea taste, sugar, strong, black milk, regular, definitely, taste like, peach green, try, crema, fruit, almond, bit, qq, great, use, delicious, bitter'
mask = np.array(Image.open('tea.jpg'))

#Run the following to generate your wordcloud
generate_wordcloud(tea, mask, 'green')

# %%
line = 'long, worth, line, wait, long line, worth wait, line long, always, tea, love, usually, good, hour, always long, long wait, wait line, best, favorite, milk tea, milk, wait long, great, boba, line always, usually long, dont, line usually, min, bubble, bubble tea, love milk, price, take, one, far, prepared, definitely worth, long worth, tea great, best boba, think worth, really, line love, prepared wait, wait always'
mask = np.array(Image.open('line.jpg'))

#Run the following to generate your wordcloud
generate_wordcloud(line, mask, 'longline')

# %%
service = 'service, customer, customer service, slow, cashier, asked, terrible, slow service, great, rude, attitude, star, one, need, friendly, min, told, said, business, person, poor, didnt, refused, counter, gave, change, want, better, girl, bad, better customer, super slow, guy, problem, last, many, number, nice, good service, way, min one, great customer, worst, one person, made, waiting, super'
mask = np.array(Image.open('star.jpg'))

#Run the following to generate your wordcloud
generate_wordcloud(service, mask, 'service2')
